# %% [markdown]
# Loading the data

# %%
import pandas as pd

# Load the dataset
file_path = '/content/housing_data.csv'
housing_data = pd.read_csv(file_path)

# Display the first few rows of the dataset
housing_data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %% [markdown]
# Trying to get more insights of the data

# %%
housing_data.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %% [markdown]
# Finding the missing values

# %%
# Check for missing values
missing_values = housing_data.isnull().sum()

# Understanding the data types
data_types = housing_data.dtypes

# Summarizing the statistical properties of the numerical features
summary_statistics = housing_data.describe()

missing_values, data_types, summary_statistics
# Out:
# (Unnamed: 0       0
#  MSSubClass       0
#  MSZoning         0
#  LotFrontage      0
#  LotArea          0
#                  ..
#  MoSold           0
#  YrSold           0
#  SaleType         0
#  SaleCondition    0
#  SalePrice        0
#  Length: 81, dtype: int64,
#  Unnamed: 0        int64
#  MSSubClass       object
#  MSZoning         object
#  LotFrontage       int64
#  LotArea           int64
#                    ...
#  MoSold           object
#  YrSold            int64
#  SaleType         object
#  SaleCondition    object
#  SalePrice         int64
#  Length: 81, dtype: object,
#          Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
#  count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
#  mean    729.500000    57.623288   10516.828082     6.099315     5.575342
#  std     421.610009    34.664304    9981.264932     1.382997     1.112799
#  min       0.000000     0.000000    1300.000000     1.000000     1.000000
# ...

# %% [markdown]
# ## Detailed Missing Values Analysis
# The dataset has two columns with missing values:
#
# GarageYrBlt: **81 missing values (5.55%)**
#
#
# Electrical: **1 missing value (0.07%)**

# %%
# Detailed analysis of missing values
missing_values_detail = housing_data.isnull().sum()
missing_values_percentage = (missing_values_detail / len(housing_data)) * 100

# Combine into a DataFrame for better readability
missing_values_df = pd.DataFrame({
    'Missing Values': missing_values_detail,
    'Percentage': missing_values_percentage
}).sort_values(by='Missing Values', ascending=False)

missing_values_df[missing_values_df['Missing Values'] > 0]
# Out:
#              Missing Values  Percentage
# Alley                  1369   93.767123
# MasVnrType              872   59.726027
# GarageYrBlt              81    5.547945
# Electrical                1    0.068493

# %% [markdown]
# ### Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# 1. Histograms for numerical features
numerical_features = ['LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt', 'SalePrice']
housing_data[numerical_features].hist(bins=20, figsize=(15, 10), layout=(3, 2))
plt.tight_layout()
plt.show()

# %%
# 2. Bar plots for categorical features
categorical_features = ['MSZoning', 'Street', 'Alley', 'SaleType', 'SaleCondition']
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 10))
for i, feature in enumerate(categorical_features):
    row, col = divmod(i, 3)
    sns.countplot(data=housing_data, x=feature, ax=axes[row, col])
    axes[row, col].set_title(f'Distribution of {feature}')
    axes[row, col].set_xticklabels(axes[row, col].get_xticklabels(), rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-bbfcfc225e6f>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[row, col].set_xticklabels(axes[row, col].get_xticklabels(), rotation=45)
# <ipython-input-7-bbfcfc225e6f>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[row, col].set_xticklabels(axes[row, col].get_xticklabels(), rotation=45)
# <ipython-input-7-bbfcfc225e6f>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[row, col].set_xticklabels(axes[row, col].get_xticklabels(), rotation=45)
# <ipython-input-7-bbfcfc225e6f>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[row, col].set_xticklabels(axes[row, col].get_xticklabels(), rotation=45)
# <ipython-input-7-bbfcfc225e6f>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[row, col].set_xticklabels(axes[row, col].get_xticklabels(), rotation=45)

# %%
# 3. Correlation heatmap
plt.figure(figsize=(15, 10))
corr_matrix = housing_data.corr()
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c2125c8c2c77> in <cell line: 3>()
#       1 # 3. Correlation heatmap
#       2 plt.figure(figsize=(15, 10))
# ----> 3 corr_matrix = housing_data.corr()
#       4 sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
#       5 plt.title('Correlation Heatmap')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# ...

# %%
# 4. Scatter plots to explore relationships with SalePrice
key_features = ['LotArea', 'YearBuilt', 'OverallQual']
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
for i, feature in enumerate(key_features):
    sns.scatterplot(data=housing_data, x=feature, y='SalePrice', ax=axes[i])
    axes[i].set_title(f'SalePrice vs {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Step 1: Handling Missing Values
# Impute missing values for 'GarageYrBlt' with the median
housing_data['GarageYrBlt'].fillna(housing_data['GarageYrBlt'].median(), inplace=True)

# %%
# Step 2: Encoding Categorical Variables
categorical_features = housing_data.select_dtypes(include=['object']).columns
housing_data = pd.get_dummies(housing_data, columns=categorical_features, drop_first=True)

# %%
# Step 3: Creating New Features
housing_data['TotalSF'] = housing_data['TotalBsmtSF'] + housing_data['1stFlrSF'] + housing_data['2ndFlrSF']

# %%
# Step 4: Normalization/Standardization
numerical_features = housing_data.select_dtypes(include=[np.number]).columns
scaler = StandardScaler()
housing_data[numerical_features] = scaler.fit_transform(housing_data[numerical_features])

# %%
# Save the transformed dataset to a new CSV file
housing_data.to_csv('transformed_housing_data.csv', index=False)

# %% [markdown]
# Further analyzing the impact of features and size on house prices.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler


# Step 1: Correlation Analysis
corr_matrix = housing_data.corr()
corr_with_saleprice = corr_matrix['SalePrice'].sort_values(ascending=False)

# Display the top 10 features most positively correlated with SalePrice
print(corr_with_saleprice.head(10))

# Step 2: Feature Importance Using Random Forest
X = housing_data.drop('SalePrice', axis=1)
y = housing_data['SalePrice']

# Train a Random Forest model
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X, y)

# Get feature importances
feature_importances = rf.feature_importances_
feature_importances_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Display the top 10 most important features
print(feature_importances_df.head(10))

# Step 3: Visualizations
# Scatter plots for key features vs SalePrice
key_features = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalSF']
for feature in key_features:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=housing_data, x=feature, y='SalePrice')
    plt.title(f'SalePrice vs {feature}')
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.grid(True)
    plt.show()

# Box plots for categorical features
categorical_features = ['OverallQual', 'GarageCars']
for feature in categorical_features:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=housing_data, x=feature, y='SalePrice')
    plt.title(f'SalePrice vs {feature}')
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.grid(True)
    plt.show()
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# TotalSF         0.780713
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# Name: SalePrice, dtype: float64
#           Feature  Importance
# 279       TotalSF    0.402396
# 2     OverallQual    0.372776
# 12       2ndFlrSF    0.028485
# 4       YearBuilt    0.023490
# 14      GrLivArea    0.012780
# 1         LotArea    0.012692
# 7      BsmtFinSF1    0.012410
# 5    YearRemodAdd    0.009301
# 9       BsmtUnfSF    0.008451
# 25     GarageArea    0.008427

# %% [markdown]
# ## Exploring historical pricing trends over time and understand market influences.

# %%
# Display the column names
print(housing_data.columns)

# Display the first few rows of the dataset
print(housing_data.head())

# Check for missing values
missing_values = housing_data.isnull().sum()
print(missing_values[missing_values > 0])


# Display the column names and the first few rows to understand its structure
print(housing_data.columns)
print(housing_data.head())

# Check if 'YrSold' is present
if 'YrSold' in housing_data.columns:
    housing_data['YrSold'] = housing_data['YrSold'].astype(int)

    # Step 1: Aggregate Sale Prices Over Time

    # Calculate average sale price per year
    average_price_per_year = housing_data.groupby('YrSold')['SalePrice'].mean().reset_index()

    # Step 2: Visualize Trends

    # Plot average sale price per year
    plt.figure(figsize=(10, 5))
    sns.lineplot(data=average_price_per_year, x='YrSold', y='SalePrice', marker='o')
    plt.title('Average Sale Price per Year')
    plt.xlabel('Year Sold')
    plt.ylabel('Average Sale Price')
    plt.grid(True)
    plt.show()


else:
    print("The column 'YrSold' is not available in the dataset.")
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        ...
#        'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_AdjLand', 'SaleCondition_Alloca', 'SaleCondition_Family',
#        'SaleCondition_Normal', 'SaleCondition_Partial', 'TotalSF'],
#       dtype='object', length=281)
#    LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0     0.212877 -0.207142     0.651479    -0.517200   1.050994      0.878668
# 1     0.645747 -0.091886    -0.071836     2.179628   0.156734     -0.429577
# 2     0.299451  0.073480     0.651479    -0.517200   0.984752      0.830215
# 3     0.068587 -0.096897     0.651479    -0.517200  -1.863632     -0.720298
# 4     0.761179  0.375148     1.374795    -0.517200   0.951632      0.733308
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  SaleType_ConLw  \
# ...
